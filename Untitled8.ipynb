# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshapatil28518-a11y/Pratiksha-Patil/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) WAP to add two numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

sum = a + b
print("Addition of two numbers is:", sum)


# 2) WAP to declare variables and display types

a = 10
b = 5.5
c = "Python"
d = True

print("Type of a:", type(a))
print("Type of b:", type(b))
print("Type of c:", type(c))
print("Type of d:", type(d))


# 3) WAP to demonstrate type casting

a = "10"
b = int(a)

print("Value of a:", a)
print("Type of a:", type(a))

print("Value after casting:", b)
print("Type after casting:", type(b))


# 4) WAP to demonstrate logical operators

a = True
b = False

print("a AND b:", a and b)
print("a OR b:", a or b)
print("NOT a:", not a)
# Out:
# Enter first number: 10
# Enter second number: 20
# Addition of two numbers is: 30
# Type of a: <class 'int'>
# Type of b: <class 'float'>
# Type of c: <class 'str'>
# Type of d: <class 'bool'>
# Value of a: 10
# Type of a: <class 'str'>
# Value after casting: 10
# Type after casting: <class 'int'>
# a AND b: False
# a OR b: True
# NOT a: False
